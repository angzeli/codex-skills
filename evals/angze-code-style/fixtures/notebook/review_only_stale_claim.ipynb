# %% [markdown]
# # Signal preparation
#
# Multiplying the signal by `1e-3` converts seconds to milliseconds.

# %%
signal = [1.0, 2.0]
scaled = [value * 1e-3 for value in signal]
print(scaled)
# Out:
# [0.001, 0.002]
